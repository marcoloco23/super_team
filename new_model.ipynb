# %%
import pandas as pd
import xgboost as xgb
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm  # For progress tracking

# %%
features = [
    #  'START_POSITION',
    "PCT_FGA_2PT",
    "PCT_AST_2PM",
    "PCT_PTS_2PT",
    "AST_PCT",
    "PCT_FG3M",
    "PCT_BLKA",
    "PCT_BLK",
    "FG3_PCT",
    "PCT_PTS",
    "PCT_FGM",
    "PCT_REB",
    "PCT_FGA",
    "E_USG_PCT",
    "REB_PCT",
    "PCT_PTS_OFF_TOV",
    "PCT_DREB",
    "OPP_OREB_PCT",
    "PCT_UAST_3PM",
    "PCT_TOV",
    "DREB_PCT",
    "PCT_FTM",
    "OPP_TOV_PCT",
    "PCT_UAST_2PM",
    "PCT_AST_3PM",
    "USG_PCT",
    "PCT_AST",
    "FG_PCT",
    "EFG_PCT",
    "TS_PCT",
    "PCT_OREB",
    "PCT_PTS_2PT_MR",
    "PCT_PF",
    "FT_PCT",
    "PCT_PTS_PAINT",
    "PCT_PTS_FT",
    "PCT_PFD",
    "PCT_FGA_3PT",
    "OPP_EFG_PCT",
    "CFG_PCT",
    "TM_TOV_PCT",
    "PCT_UAST_FGM",
    "PCT_PTS_3PT",
    "OREB_PCT",
    "PCT_PTS_FB",
    "PCT_AST_FGM",
    "UFG_PCT",
    "PCT_FG3A",
    "PCT_STL",
    "DFG_PCT",
    "OREB",
    "AST",
    "REB",
    "DFGA",
    "SAST",
    "OPP_PTS_2ND_CHANCE",
    "PFD",
    "TO",
    "FG3A",
    "STL",
    "POSS",
    "PASS",
    "UFGM",
    "FG3M",
    "PTS",
    "UFGA",
    "DRBC",
    "OPP_PTS_PAINT",
    "FTM",
    "ORBC",
    "BLKA",
    "PTS_FB",
    "CFGA",
    "PTS_PAINT",
    "TCHS",
    "CFGM",
    "PLUS_MINUS",
    "DFGM",
    "OPP_PTS_OFF_TOV",
    "PTS_OFF_TOV",
    "FGA",
    "FTA",
    "PTS_2ND_CHANCE",
    "FGM",
    "PF",
    "DREB",
    "BLK",
    "RBC",
    "OPP_PTS_FB",
    "FTAST",
    "E_OFF_RATING",
    "OFF_RATING",
    "E_NET_RATING",
    "E_DEF_RATING",
    "NET_RATING",
    "DEF_RATING",
    "E_PACE",
    "AST_RATIO",
    "DIST",
    "AST_TOV",
    "FTA_RATE",
    "OPP_FTA_RATE",
    "MIN",
    "PACE_PER40",
    "PACE",
    "PIE",
]

# %%
def win_loss_error_rate(test_predictions, test_labels):
    win_loss_predictions = np.where(test_predictions > 0, 1, 0)
    win_loss_truth = np.where(test_labels.to_numpy() > 0, 1, 0)
    return abs(win_loss_predictions - win_loss_truth).mean()

# %%
# Load the player data
player_data = pd.read_csv("data/player_data.csv")

# %%
# Define parameters
player_count = 5  # Number of players to consider per team
target = "PLUS_MINUS"
game_ids = list(set(player_data.GAME_ID))

# Placeholder for processed rows
data_rows = []

# Process each game
for game_id in tqdm(game_ids, desc="Processing games"):
    # Filter data for the current game
    game_data = player_data[player_data.GAME_ID == game_id]

    # Identify the two teams
    team_abbr = game_data["TEAM_ABBREVIATION"].unique()
    if len(team_abbr) != 2:
        continue  # Skip games without exactly two teams

    # Get top players based on minutes played
    team_1_data = (
        game_data[game_data["TEAM_ABBREVIATION"] == team_abbr[0]]
        .sort_values(by="MIN", ascending=False)
        .head(player_count)
    )
    team_2_data = (
        game_data[game_data["TEAM_ABBREVIATION"] == team_abbr[1]]
        .sort_values(by="MIN", ascending=False)
        .head(player_count)
    )

    # Ensure both teams have the required number of players
    if len(team_1_data) < player_count or len(team_2_data) < player_count:
        continue

    # Compute the target (plus-minus)
    team_1_plus_minus = team_1_data["PTS"].sum() - team_2_data["PTS"].sum()

    # Flatten the features for both teams
    team_1_features = team_1_data[features].fillna(0).values.flatten()
    team_2_features = team_2_data[features].fillna(0).values.flatten()

    # Generate column names dynamically
    feature_columns = [
        f"team1_player{i+1}_{feature}"
        for i in range(player_count)
        for feature in features
    ] + [
        f"team2_player{i+1}_{feature}"
        for i in range(player_count)
        for feature in features
    ]

    # Create original row
    data_rows.append(
        {
            "features": np.concatenate([team_1_features, team_2_features]),
            "plus_minus": team_1_plus_minus,
        }
    )

    # Create reordered row
    data_rows.append(
        {
            "features": np.concatenate([team_2_features, team_1_features]),
            "plus_minus": -team_1_plus_minus,
        }
    )

# Convert rows to DataFrame
data_df = pd.DataFrame(data_rows)

data_df = pd.concat(
    [
        pd.DataFrame(data_df["features"].tolist(), columns=feature_columns),
        data_df[["plus_minus"]],
    ],
    axis=1,
)

data_df.fillna(0, inplace=True)

# Scaling and splitting the data
X = data_df.drop(columns=["plus_minus"])
y = data_df["plus_minus"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# Final output
final_data = pd.concat(
    [pd.DataFrame(X_scaled, columns=X.columns), y.reset_index(drop=True)], axis=1
)
# Out:
# Processing games: 100%|██████████| 9830/9830 [00:08<00:00, 1166.13it/s]

# %%
# Train an XGBoost model
model = xgb.XGBRegressor(
    booster="gbtree",
    tree_method="hist",
    learning_rate=0.01,
    n_estimators=1000,
    objective="reg:squarederror",
    eval_metric="rmse",
    early_stopping_rounds=50,
)

# Train the model
eval_set = [(X_train, y_train), (X_test, y_test)]
model = model.fit(
    X_train,
    y_train,
    eval_set=eval_set,
    verbose=True,
)
# Out:
# [0]	validation_0-rmse:16.02219	validation_1-rmse:16.35190
# [1]	validation_0-rmse:15.93993	validation_1-rmse:16.27437
# [2]	validation_0-rmse:15.85832	validation_1-rmse:16.19732
# [3]	validation_0-rmse:15.77837	validation_1-rmse:16.12203
# [4]	validation_0-rmse:15.69923	validation_1-rmse:16.04734
# [5]	validation_0-rmse:15.62087	validation_1-rmse:15.97246
# [6]	validation_0-rmse:15.54389	validation_1-rmse:15.89863
# [7]	validation_0-rmse:15.46732	validation_1-rmse:15.82705
# [8]	validation_0-rmse:15.39218	validation_1-rmse:15.75558
# [9]	validation_0-rmse:15.31793	validation_1-rmse:15.68576
# [10]	validation_0-rmse:15.24442	validation_1-rmse:15.61692
# [11]	validation_0-rmse:15.17201	validation_1-rmse:15.54825
# [12]	validation_0-rmse:15.10016	validation_1-rmse:15.48056
# [13]	validation_0-rmse:15.02919	validation_1-rmse:15.41275
# [14]	validation_0-rmse:14.95848	validation_1-rmse:15.34589
# [15]	validation_0-rmse:14.88886	validation_1-rmse:15.28210
# [16]	validation_0-rmse:14.82023	validation_1-rmse:15.22051
# [17]	validation_0-rmse:14.75267	validation_1-rmse:15.15781
# [18]	validation_0-rmse:14.68525	validation_1-rmse:15.09551
# [19]	validation_0-rmse:14.61872	validation_1-rmse:15.03277
# [20]	validation_0-rmse:14.55286	validation_1-rmse:14.97231
# [21]	validation_0-rmse:14.48850	validation_1-rmse:14.91323
# [22]	validation_0-rmse:14.42435	validation_1-rmse:14.85384
# [23]	validation_0-rmse:14.36095	validation_1-rmse:14.79571
# [24]	validation_0-rmse:14.29850	validation_1-rmse:14.73857
# [25]	validation_0-rmse:14.23690	validation_1-rmse:14.68110
# [26]	validation_0-rmse:14.17554	validation_1-rmse:14.62383
# [27]	validation_0-rmse:14.11454	validation_1-rmse:14.56869
# [28]	validation_0-rmse:14.05376	validation_1-rmse:14.51386
# [29]	validation_0-rmse:13.99473	validation_1-rmse:14.45901
# [30]	validation_0-rmse:13.93598	validation_1-rmse:14.40526
# [31]	validation_0-rmse:13.87840	validation_1-rmse:14.35252
# [32]	validation_0-rmse:13.82055	validation_1-rmse:14.30065
# [33]	validation_0-rmse:13.76330	validation_1-rmse:14.24944
# [34]	validation_0-rmse:13.70728	validation_1-rmse:14.19862
# [35]	validation_0-rmse:13.65184	validation_1-rmse:14.14845
# [36]	validation_0-rmse:13.59691	validation_1-rmse:14.09888
# [37]	validation_0-rmse:13.54264	validation_1-rmse:14.04945
# [38]	validation_0-rmse:13.48883	validation_1-rmse:13.99978
# [39]	validation_0-rmse:13.43619	validation_1-rmse:13.95362
# [40]	validation_0-rmse:13.38307	validation_1-rmse:13.90604
# [41]	validation_0-rmse:13.33133	validation_1-rmse:13.86055
# [42]	validation_0-rmse:13.27949	validation_1-rmse:13.81551
# [43]	validation_0-rmse:13.22848	validation_1-rmse:13.76836
# [44]	validation_0-rmse:13.17836	validation_1-rmse:13.72267
# [45]	validation_0-rmse:13.12856	validation_1-rmse:13.67813
# [46]	validation_0-rmse:13.07927	validation_1-rmse:13.63347
# [47]	validation_0-rmse:13.03070	validation_1-rmse:13.59114
# [48]	validation_0-rmse:12.98195	validation_1-rmse:13.54857
# [49]	validation_0-rmse:12.93399	validation_1-rmse:13.50714
# [50]	validation_0-rmse:12.88704	validation_1-rmse:13.46662
# [51]	validation_0-rmse:12.84030	validation_1-rmse:13.42439
# [52]	validation_0-rmse:12.79438	validation_1-rmse:13.38403
# [53]	validation_0-rmse:12.74841	validation_1-rmse:13.34274
# [54]	validation_0-rmse:12.70310	validation_1-rmse:13.30337
# [55]	validation_0-rmse:12.65788	validation_1-rmse:13.26402
# [56]	validation_0-rmse:12.61342	validation_1-rmse:13.22471
# [57]	validation_0-rmse:12.56956	validation_1-rmse:13.18741
# [58]	validation_0-rmse:12.52645	validation_1-rmse:13.14877
# [59]	validation_0-rmse:12.48351	validation_1-rmse:13.11146
# [60]	validation_0-rmse:12.44097	validation_1-rmse:13.07399
# [61]	validation_0-rmse:12.39901	validation_1-rmse:13.03768
# [62]	validation_0-rmse:12.35710	validation_1-rmse:13.00163
# [63]	validation_0-rmse:12.31568	validation_1-rmse:12.96425
# [64]	validation_0-rmse:12.27454	validation_1-rmse:12.92831
# [65]	validation_0-rmse:12.23405	validation_1-rmse:12.89239
# [66]	validation_0-rmse:12.19410	validation_1-rmse:12.85711
# [67]	validation_0-rmse:12.15384	validation_1-rmse:12.82208
# [68]	validation_0-rmse:12.11499	validation_1-rmse:12.78892
# [69]	validation_0-rmse:12.07564	validation_1-rmse:12.75545
# [70]	validation_0-rmse:12.03721	validation_1-rmse:12.72239
# [71]	validation_0-rmse:11.99858	validation_1-rmse:12.69028
# [72]	validation_0-rmse:11.96092	validation_1-rmse:12.65785
# [73]	validation_0-rmse:11.92361	validation_1-rmse:12.62543
# [74]	validation_0-rmse:11.88651	validation_1-rmse:12.59313
# [75]	validation_0-rmse:11.84943	validation_1-rmse:12.56047
# [76]	validation_0-rmse:11.81297	validation_1-rmse:12.52904
# [77]	validation_0-rmse:11.77732	validation_1-rmse:12.49853
# [78]	validation_0-rmse:11.74145	validation_1-rmse:12.46892
# [79]	validation_0-rmse:11.70644	validation_1-rmse:12.43769
# [80]	validation_0-rmse:11.67140	validation_1-rmse:12.40827
# [81]	validation_0-rmse:11.63604	validation_1-rmse:12.37822
# [82]	validation_0-rmse:11.60143	validation_1-rmse:12.34828
# [83]	validation_0-rmse:11.56717	validation_1-rmse:12.31886
# [84]	validation_0-rmse:11.53343	validation_1-rmse:12.28981
# [85]	validation_0-rmse:11.49992	validation_1-rmse:12.26184
# [86]	validation_0-rmse:11.46654	validation_1-rmse:12.23387
# [87]	validation_0-rmse:11.43310	validation_1-rmse:12.20559
# [88]	validation_0-rmse:11.39940	validation_1-rmse:12.17658
# [89]	validation_0-rmse:11.36608	validation_1-rmse:12.15039
# [90]	validation_0-rmse:11.33374	validation_1-rmse:12.12296
# [91]	validation_0-rmse:11.30147	validation_1-rmse:12.09718
# [92]	validation_0-rmse:11.27045	validation_1-rmse:12.07194
# [93]	validation_0-rmse:11.23850	validation_1-rmse:12.04530
# [94]	validation_0-rmse:11.20754	validation_1-rmse:12.01834
# [95]	validation_0-rmse:11.17707	validation_1-rmse:11.99415
# [96]	validation_0-rmse:11.14619	validation_1-rmse:11.96885
# [97]	validation_0-rmse:11.11556	validation_1-rmse:11.94356
# [98]	validation_0-rmse:11.08544	validation_1-rmse:11.91868
# [99]	validation_0-rmse:11.05538	validation_1-rmse:11.89364
# [100]	validation_0-rmse:11.02521	validation_1-rmse:11.86984
# [101]	validation_0-rmse:10.99562	validation_1-rmse:11.84654
# [102]	validation_0-rmse:10.96659	validation_1-rmse:11.82233
# [103]	validation_0-rmse:10.93772	validation_1-rmse:11.79955
# [104]	validation_0-rmse:10.90878	validation_1-rmse:11.77662
# [105]	validation_0-rmse:10.87989	validation_1-rmse:11.75282
# [106]	validation_0-rmse:10.85141	validation_1-rmse:11.72897
# [107]	validation_0-rmse:10.82333	validation_1-rmse:11.70575
# [108]	validation_0-rmse:10.79555	validation_1-rmse:11.68294
# [109]	validation_0-rmse:10.76786	validation_1-rmse:11.65992
# [110]	validation_0-rmse:10.74005	validation_1-rmse:11.63794
# [111]	validation_0-rmse:10.71313	validation_1-rmse:11.61643
# [112]	validation_0-rmse:10.68641	validation_1-rmse:11.59553
# [113]	validation_0-rmse:10.65908	validation_1-rmse:11.57440
# [114]	validation_0-rmse:10.63234	validation_1-rmse:11.55243
# [115]	validation_0-rmse:10.60588	validation_1-rmse:11.53129
# [116]	validation_0-rmse:10.57936	validation_1-rmse:11.51069
# [117]	validation_0-rmse:10.55344	validation_1-rmse:11.49008
# [118]	validation_0-rmse:10.52748	validation_1-rmse:11.46822
# [119]	validation_0-rmse:10.50146	validation_1-rmse:11.44784
# [120]	validation_0-rmse:10.47594	validation_1-rmse:11.42791
# [121]	validation_0-rmse:10.45064	validation_1-rmse:11.40836
# [122]	validation_0-rmse:10.42531	validation_1-rmse:11.38800
# [123]	validation_0-rmse:10.40009	validation_1-rmse:11.36754
# [124]	validation_0-rmse:10.37495	validation_1-rmse:11.34846
# [125]	validation_0-rmse:10.35035	validation_1-rmse:11.32895
# [126]	validation_0-rmse:10.32639	validation_1-rmse:11.31052
# [127]	validation_0-rmse:10.30190	validation_1-rmse:11.29181
# [128]	validation_0-rmse:10.27731	validation_1-rmse:11.27294
# [129]	validation_0-rmse:10.25338	validation_1-rmse:11.25451
# [130]	validation_0-rmse:10.22957	validation_1-rmse:11.23665
# [131]	validation_0-rmse:10.20533	validation_1-rmse:11.21811
# [132]	validation_0-rmse:10.18131	validation_1-rmse:11.20010
# [133]	validation_0-rmse:10.15752	validation_1-rmse:11.18277
# [134]	validation_0-rmse:10.13434	validation_1-rmse:11.16506
# [135]	validation_0-rmse:10.11128	validation_1-rmse:11.14755
# [136]	validation_0-rmse:10.08730	validation_1-rmse:11.12906
# [137]	validation_0-rmse:10.06500	validation_1-rmse:11.11193
# [138]	validation_0-rmse:10.04216	validation_1-rmse:11.09400
# [139]	validation_0-rmse:10.01935	validation_1-rmse:11.07645
# [140]	validation_0-rmse:9.99651	validation_1-rmse:11.05955
# [141]	validation_0-rmse:9.97374	validation_1-rmse:11.04207
# [142]	validation_0-rmse:9.95157	validation_1-rmse:11.02549
# [143]	validation_0-rmse:9.92895	validation_1-rmse:11.00849
# [144]	validation_0-rmse:9.90629	validation_1-rmse:10.99135
# [145]	validation_0-rmse:9.88430	validation_1-rmse:10.97381
# [146]	validation_0-rmse:9.86249	validation_1-rmse:10.95779
# [147]	validation_0-rmse:9.84036	validation_1-rmse:10.94114
# [148]	validation_0-rmse:9.81826	validation_1-rmse:10.92496
# [149]	validation_0-rmse:9.79649	validation_1-rmse:10.90823
# [150]	validation_0-rmse:9.77505	validation_1-rmse:10.89196
# [151]	validation_0-rmse:9.75376	validation_1-rmse:10.87567
# [152]	validation_0-rmse:9.73228	validation_1-rmse:10.85971
# [153]	validation_0-rmse:9.71095	validation_1-rmse:10.84352
# [154]	validation_0-rmse:9.68889	validation_1-rmse:10.82556
# [155]	validation_0-rmse:9.66721	validation_1-rmse:10.80840
# [156]	validation_0-rmse:9.64573	validation_1-rmse:10.79201
# [157]	validation_0-rmse:9.62490	validation_1-rmse:10.77673
# [158]	validation_0-rmse:9.60322	validation_1-rmse:10.75949
# [159]	validation_0-rmse:9.58208	validation_1-rmse:10.74333
# [160]	validation_0-rmse:9.56092	validation_1-rmse:10.72738
# [161]	validation_0-rmse:9.54073	validation_1-rmse:10.71183
# [162]	validation_0-rmse:9.52024	validation_1-rmse:10.69664
# [163]	validation_0-rmse:9.49934	validation_1-rmse:10.68067
# [164]	validation_0-rmse:9.47909	validation_1-rmse:10.66479
# [165]	validation_0-rmse:9.45968	validation_1-rmse:10.64992
# [166]	validation_0-rmse:9.43862	validation_1-rmse:10.63428
# [167]	validation_0-rmse:9.41804	validation_1-rmse:10.61842
# [168]	validation_0-rmse:9.39823	validation_1-rmse:10.60336
# [169]	validation_0-rmse:9.37775	validation_1-rmse:10.58773
# [170]	validation_0-rmse:9.35820	validation_1-rmse:10.57240
# [171]	validation_0-rmse:9.33901	validation_1-rmse:10.55801
# [172]	validation_0-rmse:9.31882	validation_1-rmse:10.54266
# [173]	validation_0-rmse:9.29919	validation_1-rmse:10.52820
# [174]	validation_0-rmse:9.27919	validation_1-rmse:10.51287
# [175]	validation_0-rmse:9.25911	validation_1-rmse:10.49782
# [176]	validation_0-rmse:9.23976	validation_1-rmse:10.48406
# [177]	validation_0-rmse:9.22160	validation_1-rmse:10.47054
# [178]	validation_0-rmse:9.20225	validation_1-rmse:10.45532
# [179]	validation_0-rmse:9.18327	validation_1-rmse:10.44141
# [180]	validation_0-rmse:9.16395	validation_1-rmse:10.42711
# [181]	validation_0-rmse:9.14480	validation_1-rmse:10.41179
# [182]	validation_0-rmse:9.12619	validation_1-rmse:10.39814
# [183]	validation_0-rmse:9.10754	validation_1-rmse:10.38452
# [184]	validation_0-rmse:9.08937	validation_1-rmse:10.37044
# [185]	validation_0-rmse:9.07036	validation_1-rmse:10.35703
# [186]	validation_0-rmse:9.05156	validation_1-rmse:10.34310
# [187]	validation_0-rmse:9.03298	validation_1-rmse:10.32811
# [188]	validation_0-rmse:9.01427	validation_1-rmse:10.31359
# [189]	validation_0-rmse:8.99589	validation_1-rmse:10.29885
# [190]	validation_0-rmse:8.97824	validation_1-rmse:10.28602
# [191]	validation_0-rmse:8.96029	validation_1-rmse:10.27229
# [192]	validation_0-rmse:8.94213	validation_1-rmse:10.25945
# [193]	validation_0-rmse:8.92511	validation_1-rmse:10.24673
# [194]	validation_0-rmse:8.90687	validation_1-rmse:10.23313
# [195]	validation_0-rmse:8.88956	validation_1-rmse:10.21925
# [196]	validation_0-rmse:8.87179	validation_1-rmse:10.20606
# [197]	validation_0-rmse:8.85447	validation_1-rmse:10.19309
# [198]	validation_0-rmse:8.83668	validation_1-rmse:10.18005
# [199]	validation_0-rmse:8.81929	validation_1-rmse:10.16745
# [200]	validation_0-rmse:8.80233	validation_1-rmse:10.15558
# [201]	validation_0-rmse:8.78534	validation_1-rmse:10.14169
# [202]	validation_0-rmse:8.76885	validation_1-rmse:10.12935
# [203]	validation_0-rmse:8.75168	validation_1-rmse:10.11654
# [204]	validation_0-rmse:8.73467	validation_1-rmse:10.10421
# [205]	validation_0-rmse:8.71818	validation_1-rmse:10.09138
# [206]	validation_0-rmse:8.70164	validation_1-rmse:10.07908
# [207]	validation_0-rmse:8.68500	validation_1-rmse:10.06699
# [208]	validation_0-rmse:8.66878	validation_1-rmse:10.05592
# [209]	validation_0-rmse:8.65258	validation_1-rmse:10.04329
# [210]	validation_0-rmse:8.63626	validation_1-rmse:10.03144
# [211]	validation_0-rmse:8.62037	validation_1-rmse:10.01997
# [212]	validation_0-rmse:8.60418	validation_1-rmse:10.00837
# [213]	validation_0-rmse:8.58822	validation_1-rmse:9.99548
# [214]	validation_0-rmse:8.57236	validation_1-rmse:9.98333
# [215]	validation_0-rmse:8.55608	validation_1-rmse:9.97022
# [216]	validation_0-rmse:8.54050	validation_1-rmse:9.95979
# [217]	validation_0-rmse:8.52475	validation_1-rmse:9.94837
# [218]	validation_0-rmse:8.50882	validation_1-rmse:9.93603
# [219]	validation_0-rmse:8.49298	validation_1-rmse:9.92498
# [220]	validation_0-rmse:8.47705	validation_1-rmse:9.91336
# [221]	validation_0-rmse:8.46142	validation_1-rmse:9.90143
# [222]	validation_0-rmse:8.44580	validation_1-rmse:9.89050
# [223]	validation_0-rmse:8.42990	validation_1-rmse:9.87974
# [224]	validation_0-rmse:8.41508	validation_1-rmse:9.86870
# [225]	validation_0-rmse:8.39931	validation_1-rmse:9.85628
# [226]	validation_0-rmse:8.38443	validation_1-rmse:9.84573
# [227]	validation_0-rmse:8.36720	validation_1-rmse:9.83423
# [228]	validation_0-rmse:8.35040	validation_1-rmse:9.82196
# [229]	validation_0-rmse:8.33545	validation_1-rmse:9.81198
# [230]	validation_0-rmse:8.31829	validation_1-rmse:9.79890
# [231]	validation_0-rmse:8.30176	validation_1-rmse:9.78721
# [232]	validation_0-rmse:8.28524	validation_1-rmse:9.77487
# [233]	validation_0-rmse:8.26860	validation_1-rmse:9.76302
# [234]	validation_0-rmse:8.25192	validation_1-rmse:9.75112
# [235]	validation_0-rmse:8.23613	validation_1-rmse:9.73999
# [236]	validation_0-rmse:8.21974	validation_1-rmse:9.72763
# [237]	validation_0-rmse:8.20312	validation_1-rmse:9.71539
# [238]	validation_0-rmse:8.18710	validation_1-rmse:9.70358
# [239]	validation_0-rmse:8.17088	validation_1-rmse:9.69114
# [240]	validation_0-rmse:8.15519	validation_1-rmse:9.67924
# [241]	validation_0-rmse:8.13906	validation_1-rmse:9.66813
# [242]	validation_0-rmse:8.12386	validation_1-rmse:9.65766
# [243]	validation_0-rmse:8.10776	validation_1-rmse:9.64594
# [244]	validation_0-rmse:8.09196	validation_1-rmse:9.63386
# [245]	validation_0-rmse:8.07673	validation_1-rmse:9.62200
# [246]	validation_0-rmse:8.06087	validation_1-rmse:9.61041
# [247]	validation_0-rmse:8.04589	validation_1-rmse:9.59942
# [248]	validation_0-rmse:8.03075	validation_1-rmse:9.58802
# [249]	validation_0-rmse:8.01500	validation_1-rmse:9.57616
# [250]	validation_0-rmse:7.99968	validation_1-rmse:9.56507
# [251]	validation_0-rmse:7.98459	validation_1-rmse:9.55409
# [252]	validation_0-rmse:7.96954	validation_1-rmse:9.54226
# [253]	validation_0-rmse:7.95478	validation_1-rmse:9.53209
# [254]	validation_0-rmse:7.94017	validation_1-rmse:9.52133
# [255]	validation_0-rmse:7.92499	validation_1-rmse:9.51041
# [256]	validation_0-rmse:7.90984	validation_1-rmse:9.49930
# [257]	validation_0-rmse:7.89543	validation_1-rmse:9.48897
# [258]	validation_0-rmse:7.88036	validation_1-rmse:9.47721
# [259]	validation_0-rmse:7.86593	validation_1-rmse:9.46548
# [260]	validation_0-rmse:7.85121	validation_1-rmse:9.45466
# [261]	validation_0-rmse:7.83630	validation_1-rmse:9.44373
# [262]	validation_0-rmse:7.82172	validation_1-rmse:9.43290
# [263]	validation_0-rmse:7.80742	validation_1-rmse:9.42331
# [264]	validation_0-rmse:7.79346	validation_1-rmse:9.41253
# [265]	validation_0-rmse:7.77926	validation_1-rmse:9.40127
# [266]	validation_0-rmse:7.76486	validation_1-rmse:9.39018
# [267]	validation_0-rmse:7.75071	validation_1-rmse:9.37923
# [268]	validation_0-rmse:7.73677	validation_1-rmse:9.36874
# [269]	validation_0-rmse:7.72262	validation_1-rmse:9.35799
# [270]	validation_0-rmse:7.70832	validation_1-rmse:9.34773
# [271]	validation_0-rmse:7.69437	validation_1-rmse:9.33774
# [272]	validation_0-rmse:7.68051	validation_1-rmse:9.32695
# [273]	validation_0-rmse:7.66662	validation_1-rmse:9.31550
# [274]	validation_0-rmse:7.65319	validation_1-rmse:9.30515
# [275]	validation_0-rmse:7.63943	validation_1-rmse:9.29525
# [276]	validation_0-rmse:7.62575	validation_1-rmse:9.28570
# [277]	validation_0-rmse:7.61251	validation_1-rmse:9.27574
# [278]	validation_0-rmse:7.59862	validation_1-rmse:9.26615
# [279]	validation_0-rmse:7.58533	validation_1-rmse:9.25698
# [280]	validation_0-rmse:7.57197	validation_1-rmse:9.24824
# [281]	validation_0-rmse:7.55901	validation_1-rmse:9.23858
# [282]	validation_0-rmse:7.54585	validation_1-rmse:9.22866
# [283]	validation_0-rmse:7.53220	validation_1-rmse:9.21844
# [284]	validation_0-rmse:7.51904	validation_1-rmse:9.20932
# [285]	validation_0-rmse:7.50582	validation_1-rmse:9.19898
# [286]	validation_0-rmse:7.49250	validation_1-rmse:9.18905
# [287]	validation_0-rmse:7.47872	validation_1-rmse:9.17921
# [288]	validation_0-rmse:7.46604	validation_1-rmse:9.17035
# [289]	validation_0-rmse:7.45373	validation_1-rmse:9.16163
# [290]	validation_0-rmse:7.44082	validation_1-rmse:9.15248
# [291]	validation_0-rmse:7.42801	validation_1-rmse:9.14326
# [292]	validation_0-rmse:7.41475	validation_1-rmse:9.13335
# [293]	validation_0-rmse:7.40179	validation_1-rmse:9.12398
# [294]	validation_0-rmse:7.38970	validation_1-rmse:9.11565
# [295]	validation_0-rmse:7.37728	validation_1-rmse:9.10585
# [296]	validation_0-rmse:7.36468	validation_1-rmse:9.09598
# [297]	validation_0-rmse:7.35212	validation_1-rmse:9.08767
# [298]	validation_0-rmse:7.33933	validation_1-rmse:9.07853
# [299]	validation_0-rmse:7.32667	validation_1-rmse:9.06976
# [300]	validation_0-rmse:7.31376	validation_1-rmse:9.06001
# [301]	validation_0-rmse:7.30139	validation_1-rmse:9.05092
# [302]	validation_0-rmse:7.28895	validation_1-rmse:9.04113
# [303]	validation_0-rmse:7.27690	validation_1-rmse:9.03205
# [304]	validation_0-rmse:7.26468	validation_1-rmse:9.02396
# [305]	validation_0-rmse:7.25239	validation_1-rmse:9.01480
# [306]	validation_0-rmse:7.24031	validation_1-rmse:9.00591
# [307]	validation_0-rmse:7.22798	validation_1-rmse:8.99669
# [308]	validation_0-rmse:7.21646	validation_1-rmse:8.98950
# [309]	validation_0-rmse:7.20477	validation_1-rmse:8.98127
# [310]	validation_0-rmse:7.19309	validation_1-rmse:8.97227
# [311]	validation_0-rmse:7.18126	validation_1-rmse:8.96334
# [312]	validation_0-rmse:7.16910	validation_1-rmse:8.95477
# [313]	validation_0-rmse:7.15723	validation_1-rmse:8.94537
# [314]	validation_0-rmse:7.14526	validation_1-rmse:8.93611
# [315]	validation_0-rmse:7.13321	validation_1-rmse:8.92737
# [316]	validation_0-rmse:7.12201	validation_1-rmse:8.92014
# [317]	validation_0-rmse:7.11091	validation_1-rmse:8.91171
# [318]	validation_0-rmse:7.09948	validation_1-rmse:8.90288
# [319]	validation_0-rmse:7.08771	validation_1-rmse:8.89396
# [320]	validation_0-rmse:7.07620	validation_1-rmse:8.88539
# [321]	validation_0-rmse:7.06462	validation_1-rmse:8.87689
# [322]	validation_0-rmse:7.05302	validation_1-rmse:8.86813
# [323]	validation_0-rmse:7.04142	validation_1-rmse:8.85974
# [324]	validation_0-rmse:7.03071	validation_1-rmse:8.85171
# [325]	validation_0-rmse:7.01879	validation_1-rmse:8.84345
# [326]	validation_0-rmse:7.00762	validation_1-rmse:8.83505
# [327]	validation_0-rmse:6.99601	validation_1-rmse:8.82706
# [328]	validation_0-rmse:6.98435	validation_1-rmse:8.81806
# [329]	validation_0-rmse:6.97332	validation_1-rmse:8.80960
# [330]	validation_0-rmse:6.96254	validation_1-rmse:8.80100
# [331]	validation_0-rmse:6.95123	validation_1-rmse:8.79317
# [332]	validation_0-rmse:6.94064	validation_1-rmse:8.78476
# [333]	validation_0-rmse:6.92954	validation_1-rmse:8.77668
# [334]	validation_0-rmse:6.91811	validation_1-rmse:8.76778
# [335]	validation_0-rmse:6.90755	validation_1-rmse:8.76088
# [336]	validation_0-rmse:6.89656	validation_1-rmse:8.75253
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      12 # Train the model
#      13 eval_set = [(X_train, y_train), (X_test, y_test)]
# ---> 14 model = model.fit(
#      15     X_train,
#      16     y_train,
#      17     eval_set=eval_set,
#      18     verbose=True,
#      19 )
#
# File /opt/anaconda3/envs/eywa/lib/python3.10/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/anaconda3/envs/eywa/lib/python3.10/site-packages/xgboost/sklearn.py:1108, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1105     obj = None
#    1107 model, metric, params = self._configure_fit(xgb_model, params)
# -> 1108 self._Booster = train(
#    1109     params,
#    1110     train_dmatrix,
#    1111     self.get_num_boosting_rounds(),
#    1112     evals=evals,
#    1113     early_stopping_rounds=self.early_stopping_rounds,
#    1114     evals_result=evals_result,
#    1115     obj=obj,
#    1116     custom_metric=metric,
#    1117     verbose_eval=verbose,
#    1118     xgb_model=model,
#    1119     callbacks=self.callbacks,
#    1120 )
#    1122 self._set_evaluation_result(evals_result)
#    1123 return self
#
# File /opt/anaconda3/envs/eywa/lib/python3.10/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/anaconda3/envs/eywa/lib/python3.10/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /opt/anaconda3/envs/eywa/lib/python3.10/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# Print feature importances
importances = model.feature_importances_
feature_importance_df = pd.DataFrame(
    {"Feature": X.columns, "Importance": importances}
).sort_values(by="Importance", ascending=False)

print("Top 10 Most Important Features:")
print(feature_importance_df.head(10))

# Evaluate model performance
train_rmse = np.sqrt(((model.predict(X_train) - y_train) ** 2).mean())
test_rmse = np.sqrt(((model.predict(X_test) - y_test) ** 2).mean())

print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")

# Evaluate win-loss error rate
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
train_error_rate = win_loss_error_rate(train_predictions, y_train)
test_error_rate = win_loss_error_rate(test_predictions, y_test)

print(f"Train Win-Loss Error Rate: {train_error_rate}")
print(f"Test Win-Loss Error Rate: {test_error_rate}")

# R2 score
train_r2 = r2_score(y_train, train_predictions)
test_r2 = r2_score(y_test, test_predictions)

print(f"Train R2 Score: {train_r2}")
print(f"Test R2 Score: {test_r2}")

# %%
model.save_model(f"models/{player_count}_player_model.json")

# %%
model_5 = xgb.XGBRegressor()
model_5.load_model("models/5_player_model.json")

# %%
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm

# Load the player data
player_data = pd.read_csv("data/player_data.csv")

# Define parameters
player_count = 5  # Number of players per team
target = "PLUS_MINUS"
game_ids = list(set(player_data.GAME_ID))

# Placeholder for processed rows
data_rows = []

# Process each game
for game_id in tqdm(game_ids, desc="Processing games"):
    # Filter data for the current game
    game_data = player_data[player_data.GAME_ID == game_id]

    # Identify the two teams
    team_abbr = game_data["TEAM_ABBREVIATION"].unique()
    if len(team_abbr) != 2:
        continue  # Skip games without exactly two teams

    # Get top players based on minutes played
    team_1_data = (
        game_data[game_data["TEAM_ABBREVIATION"] == team_abbr[0]]
        .sort_values(by="MIN", ascending=False)
        .head(player_count)
    )
    team_2_data = (
        game_data[game_data["TEAM_ABBREVIATION"] == team_abbr[1]]
        .sort_values(by="MIN", ascending=False)
        .head(player_count)
    )

    # Ensure both teams have the required number of players
    if len(team_1_data) < player_count or len(team_2_data) < player_count:
        continue

    # Compute the target (plus-minus)
    team_1_plus_minus = team_1_data["PTS"].sum() - team_2_data["PTS"].sum()

    # Flatten the features for both teams
    team_1_features = team_1_data[features].fillna(0).values
    team_2_features = team_2_data[features].fillna(0).values

    # Append the data
    data_rows.append(
        {
            "team_1_features": team_1_features,
            "team_2_features": team_2_features,
            "plus_minus": team_1_plus_minus,
        }
    )

# Convert to DataFrame
data_df = pd.DataFrame(data_rows)

# Combine team features into sequences
data_df["features"] = data_df.apply(
    lambda row: np.concatenate(
        [row["team_1_features"], row["team_2_features"]], axis=0
    ),
    axis=1,
)

# Extract features and target
X = np.stack(data_df["features"].values)
y = data_df["plus_minus"].values

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)
# Out:
# Processing games: 100%|██████████| 9830/9830 [00:07<00:00, 1329.54it/s]

# %%
import torch.nn as nn


class TransformerRegressor(nn.Module):
    def __init__(
        self, input_dim, num_tokens, hidden_dim=128, num_heads=4, num_layers=2
    ):
        super(TransformerRegressor, self).__init__()
        self.input_dim = input_dim
        self.num_tokens = num_tokens
        self.hidden_dim = hidden_dim

        # Input projection
        self.fc_in = nn.Linear(input_dim, hidden_dim)

        # Positional encoding
        self.positional_encoding = nn.Parameter(torch.zeros(1, num_tokens, hidden_dim))

        # Transformer encoder
        self.encoder_layer = nn.TransformerEncoderLayer(
            d_model=hidden_dim, nhead=num_heads, batch_first=True
        )
        self.transformer = nn.TransformerEncoder(
            self.encoder_layer, num_layers=num_layers
        )

        # Regression head
        self.fc_out = nn.Linear(hidden_dim * num_tokens, 1)

    def forward(self, x):
        # Project inputs to hidden dimension
        x = self.fc_in(x)

        # Add positional encoding
        x = x + self.positional_encoding

        # Transformer
        x = self.transformer(x)

        # Flatten and regression head
        x = x.view(x.size(0), -1)  # Flatten
        x = self.fc_out(x)  # Regression output
        return x

# %%
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm

# DataLoader
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32)

# Initialize model, loss, optimizer
model = TransformerRegressor(
    input_dim=len(features),
    num_tokens=2 * player_count,
    hidden_dim=128,
    num_heads=4,
    num_layers=2,
)
criterion = nn.MSELoss()
optimizer = Adam(model.parameters(), lr=1e-3)

# Training loop
epochs = 10
for epoch in range(epochs):
    model.train()
    train_loss = 0.0
    for batch in tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}"):
        X_batch, y_batch = batch
        optimizer.zero_grad()
        predictions = model(X_batch)
        loss = criterion(predictions, y_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    print(f"Epoch {epoch+1}, Training Loss: {train_loss / len(train_loader)}")

# Evaluate on test set
model.eval()
test_loss = 0.0
with torch.no_grad():
    for batch in test_loader:
        X_batch, y_batch = batch
        predictions = model(X_batch)
        loss = criterion(predictions, y_batch)
        test_loss += loss.item()
print(f"Test Loss: {test_loss / len(test_loader)}")
# Out:
# Epoch 1/10: 100%|██████████| 246/246 [00:04<00:00, 51.42it/s]
# Epoch 1, Training Loss: 60.94430138425129
# Epoch 2/10: 100%|██████████| 246/246 [00:04<00:00, 51.69it/s]
# Epoch 2, Training Loss: 17.542549179821478
# Epoch 3/10: 100%|██████████| 246/246 [00:04<00:00, 51.79it/s]
# Epoch 3, Training Loss: 11.539365869227463
# Epoch 4/10: 100%|██████████| 246/246 [00:05<00:00, 49.09it/s]
# Epoch 4, Training Loss: 8.602222748888217
# Epoch 5/10: 100%|██████████| 246/246 [00:04<00:00, 49.78it/s]
# Epoch 5, Training Loss: 6.825972472749105
# Epoch 6/10: 100%|██████████| 246/246 [00:04<00:00, 51.78it/s]
# Epoch 6, Training Loss: 6.170281768814335
# Epoch 7/10: 100%|██████████| 246/246 [00:04<00:00, 51.97it/s]
# Epoch 7, Training Loss: 5.020171988301161
# Epoch 8/10: 100%|██████████| 246/246 [00:04<00:00, 50.36it/s]
# Epoch 8, Training Loss: 4.82576222875254
# Epoch 9/10: 100%|██████████| 246/246 [00:05<00:00, 47.35it/s]
# Epoch 9, Training Loss: 4.574093804126832
# Epoch 10/10: 100%|██████████| 246/246 [00:04<00:00, 51.12it/s]
# Epoch 10, Training Loss: 3.9353739876088087
# Test Loss: 3.917992930258474

# %%
from sklearn.metrics import mean_squared_error

# Predictions
y_pred = model(X_test_tensor).detach().numpy()
rmse = np.sqrt(mean_squared_error(y_test_tensor.numpy(), y_pred))
print(f"Test RMSE: {rmse}")
# Out:
# Test RMSE: 1.9811452627182007
